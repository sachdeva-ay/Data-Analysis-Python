# %% [markdown]
# # Question 1

# %%
#Analyzing the activity taking place in the entire maildin hour wise.

import os
import operator
from email.parser import Parser
rootdir = "C:\\Users\\smrut\\midterm\\data\\enron\\enron_mail_20150507\\maildir\\lay-k"


def email_analyse(inputfile, to_email_list, from_email_list, email_body, email_time):
    with open(inputfile, "r") as f:
        data = f.read()

    email = Parser().parsestr(data)

    to_email_list.append(email['to'])
    from_email_list.append(email['from'])

    email_body.append(email.get_payload())
    email_time.append(email.get('date'))


to_email_list = []
from_email_list = []
email_body = []
email_time=[]
t=[]
time=[]
time_dic={}

for directory, subdirectory, filenames in  os.walk(rootdir):
    for filename in filenames:
        email_analyse(os.path.join(directory, filename), to_email_list, from_email_list, email_body, email_time )
            
with open("email_time.txt","w") as f:
    for email_tim in email_time:
        if email_tim:
            email_tim=email_tim.split(" ")
            for time_1 in email_tim[4:5]:
                time_1=time_1.split(":")
                t.append(time_1)
                for t1 in time_1[0:1]:
                    #print(time_1)
                    time.append(t1)

for digit in time:
    if digit in time_dic:
        time_dic[digit] +=1
    else:
        time_dic[digit]=1
#print (time_dic)

sorted_x = sorted(time_dic.items(), key=operator.itemgetter(1))
print(sorted_x)

# %%
#Analyzing only Lay Kenneth File
#Analysing the from andto fields of Kenneth Lay.
import os
from collections import Counter

from email.parser import Parser
rootdir = "C:\\Users\\smrut\\midterm\\data\\enron\\enron_mail_20150507\\maildir\\lay-k"


def email_analyse(inputfile, to_email_list, from_email_list, email_body):
    with open(inputfile, "r") as f:
        data = f.read()

    email = Parser().parsestr(data)  
    
    if email['to']:
        email_to = email['to']
        email_to = email_to.replace("\n", "")
        email_to = email_to.replace("\t", "")
        email_to = email_to.replace(" ", "")

        email_to = email_to.split(",")

        for email_to_1 in email_to:
            to_email_list.append(email_to_1)

    from_email_list.append(email['from'])

    email_body.append(email.get_payload())


to_email_list = []
from_email_list = []
email_body = []

for directory, subdirectory, filenames in  os.walk(rootdir):
    for filename in filenames:
        email_analyse(os.path.join(directory, filename), to_email_list, from_email_list, email_body )

print("\nTo email adresses: \n")
print(Counter(to_email_list).most_common(15))

print("\nFrom email adresses: \n")
print(Counter(from_email_list).most_common(15))

'''
with open("to_email_list.txt", "w") as f:
    for to_email in to_email_list:
        if to_email:
            f.write(to_email)
            f.write("\n")
with open("from_email_list.txt", "w") as f:
    for from_email in from_email_list:
        if from_email:
            f.write(from_email)
            f.write("\n")        
'''   
with open("email_body.txt", "w") as f:
    for email_bod in email_body:
        if email_bod:
            f.write(email_bod)
            f.write("\n") 
            
            
#Most of the emails were sent with Lay’s own email address (as we are looking at his data). It seemed he had two email addreses: kenneth.lay@enron.com and klay@enron.com

#The most emails he received were from Rosalee Fleming.
# Out:
# To email adresses:
#
# [('kenneth.lay@enron.com', 2039), ('klay@enron.com', 1903), ('jeff.skilling@enron.com', 372), ('mark.koenig@enron.com', 313), ('greg.whalley@enron.com', 304), ('mark.frevert@enron.com', 304), ('steven.kean@enron.com', 278), ('mike.mcconnell@enron.com', 261), ('jeffrey.mcmahon@enron.com', 251), ('john.sherriff@enron.com', 244), ('cliff.baxter@enron.com', 241), ('andrew.fastow@enron.com', 173), ('cindy.olson@enron.com', 168), ('louise.kitchen@enron.com', 162), ('richard.causey@enron.com', 162)]
#
# From email adresses:
#
# ...

# %%
import os
from collections import Counter

from email.parser import Parser
rootdir = "C:\\Users\\smrut\\midterm\\data\\enron\\enron_mail_20150507\\maildir"


def email_analyse(inputfile, to_email_list, from_email_list, email_body):
    with open(inputfile, "r") as f:
        data = f.read()

    email = Parser().parsestr(data)
    
    if email['to']:
        email_to = email['to']
        email_to = email_to.replace("\n", "")
        email_to = email_to.replace("\t", "")
        email_to = email_to.replace(" ", "")

        email_to = email_to.split(",")

        for email_to_1 in email_to:
            to_email_list.append(email_to_1)

    from_email_list.append(email['from'])
    email_body.append(email.get_payload())

to_email_list = []
from_email_list = []
email_body = []

for directory, subdirectory, filenames in  os.walk(rootdir):
    for filename in filenames:
        email_analyse(os.path.join(directory, filename), to_email_list, from_email_list, email_body )

print("\nTo email adresses: \n")
print(Counter(to_email_list).most_common(10))

print("\nFrom email adresses: \n")
print(Counter(from_email_list).most_common(10))

print(email_body)[0:10]


#In the To list, the top person is Richard Shapiro.
#The highest From field, which is emails received from, is Kay Mann.
# Out:
# To email adresses:
#
# [('richard.shapiro@enron.com', 15149), ('jeff.dasovich@enron.com', 14207), ('tana.jones@enron.com', 12828), ('steven.kean@enron.com', 12754), ('sara.shackleton@enron.com', 11433), ('james.steffes@enron.com', 10347), ('mark.taylor@enron.com', 9787), ('pete.davis@enron.com', 9281), ('susan.mara@enron.com', 9064), ('paul.kaufman@enron.com', 8522)]

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

with open("email_body.txt", "r") as f:
    data = f.read()


words= word_tokenize(data)

useful_words = [word  for word in words if word not in stopwords.words('English')]

frequency = nltk.FreqDist(useful_words)

print(frequency.most_common(100))
# Out:
# [(',', 82443), ('.', 59781), ('--', 27631), ('?', 26239), ('>', 22136), (':', 21640), ('@', 20084), ('Enron', 14536), ('I', 13970), ("'s", 10955), ("''", 10811), (')', 10030), ('(', 9479), ('<', 7817), ('-', 7340), ('The', 7138), (';', 5981), ('company', 5943), ('``', 5721), ('employees', 5234), ('$', 4969), ('energy', 4437), ('To', 4020), ('made', 3994), ('=20', 3921), ('would', 3843), ('California', 3734), ('Lay', 3468), ('consumers', 3441), ('Ken', 3402), ('http', 3213), ('Please', 3200), ('We', 3051), ('&', 3048), ('million', 2866), ('!', 2678), ('stock', 2670), ('Mr.', 2621), ('pay', 2491), ('...', 2444), ('funds', 2393), ('retirement', 2329), ('bills', 2298), ('bankruptcy', 2297), ('millions', 2294), ('donate', 2260), ('declared', 2250), ("n't", 2217), ('year', 2201), ('As', 2199), ('New', 2190), ('ENRON', 2182), ('help', 2154), ('information', 2095), ('know', 2086), ('last', 2060), ('time', 2039), ('*', 2036), ('well', 1998), ('If', 1933), ('us', 1911), ('many', 1899), ("'", 1
# ...

# %%
# Analysing only for the word bankrupcy and when its occurance increased the most
#Analyzing only Lay Kenneth File

import os
from collections import Counter

from email.parser import Parser
rootdir = "C:\\Users\\smrut\\midterm\\data\\enron\\enron_mail_20150507\\maildir\\lay"


def email_analyse(inputfile, to_email_list, from_email_list, email_body):
    with open(inputfile, "r") as f:
        data = f.read()

    email = Parser().parsestr(data)  
    
    if email['to']:
        email_to = email['to']
        email_to = email_to.replace("\n", "")
        email_to = email_to.replace("\t", "")
        email_to = email_to.replace(" ", "")

        email_to = email_to.split(",")

        for email_to_1 in email_to:
            to_email_list.append(email_to_1)

    from_email_list.append(email['from'])

    email_body.append(email.get_payload())


to_email_list = []
from_email_list = []
email_body = []

for directory, subdirectory, filenames in  os.walk(rootdir):
    #print(directory, subdirectory, filenames)
    for subdirector in subdirectory:
        if subdirector=="sent" or subdirector=="_sent_mail":
        #print("Hi")
            #print(directory,subdirector)
            path=os.path.join(directory,subdirector)
            #print(path)
            #for filename in filenames:
                for filename in subdirector:
                    print(filename)
                #print(directory,subdirector, filename)
                    email_analyse(filename, to_email_list, from_email_list, email_body )
                else:
                    print("Hii")
        else:
            print("Hi")


print("\nTo email adresses: \n")
print(Counter(to_email_list).most_common(15))

print("\nFrom email adresses: \n")
print(Counter(from_email_list).most_common(15))

'''
with open("to_email_list.txt", "w") as f:
    for to_email in to_email_list:
        if to_email:
            f.write(to_email)
            f.write("\n")
with open("from_email_list.txt", "w") as f:
    for from_email in from_email_list:
        if from_email:
            f.write(from_email)
            f.write("\n")        
'''   
with open("email_body.txt", "w") as f:
    for email_bod in email_body:
        if email_bod:
            f.write(email_bod)
            f.write("\n") 
            
            
#Most of the emails were sent with Lay’s own email address (as we are looking at his data). It seemed he had two email addreses: kenneth.lay@enron.com and klay@enron.com

#The most emails he received were from Rosalee Fleming.
# Out:
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hii
# Hii
# Hii
# Hii
# Hii
# Hii
# Hii
# Hii
# Hii
# Hii
# Hii
# Hii
# Hii
# Hii
# Hii
# Hii
# Hii
# Hii
# Hii
# Hii
# Hii
# Hii
# Hii
# Hii
# Hii
# Hii
# Hii
# Hii
# Hii
# Hii
# Hii
# Hii
# Hii
# Hii
# Hii
# Hii
# Hii
# Hii
# Hii
# Hii
# Hii
# Hii
# Hii
# Hii
# Hii
# Hii
# Hii
# Hii
# Hii
# Hii
# Hii
# Hii
# Hii
# Hii
# Hii
# ...
