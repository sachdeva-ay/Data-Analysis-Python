# %%
import nltk

# %%
from nltk.corpus import inaugural
inaugural.fileids()
# Out:
# ['1789-Washington.txt',
#  '1793-Washington.txt',
#  '1797-Adams.txt',
#  '1801-Jefferson.txt',
#  '1805-Jefferson.txt',
#  '1809-Madison.txt',
#  '1813-Madison.txt',
#  '1817-Monroe.txt',
#  '1821-Monroe.txt',
#  '1825-Adams.txt',
#  '1829-Jackson.txt',
#  '1833-Jackson.txt',
#  '1837-VanBuren.txt',
#  '1841-Harrison.txt',
#  '1845-Polk.txt',
#  '1849-Taylor.txt',
#  '1853-Pierce.txt',
#  '1857-Buchanan.txt',
#  '1861-Lincoln.txt',
#  '1865-Lincoln.txt',
#  '1869-Grant.txt',
#  '1873-Grant.txt',
#  '1877-Hayes.txt',
#  '1881-Garfield.txt',
#  '1885-Cleveland.txt',
#  '1889-Harrison.txt',
#  '1893-Cleveland.txt',
#  '1897-McKinley.txt',
#  '1901-McKinley.txt',
#  '1905-Roosevelt.txt',
#  '1909-Taft.txt',
#  '1913-Wilson.txt',
#  '1917-Wilson.txt',
#  '1921-Harding.txt',
#  '1925-Coolidge.txt',
#  '1929-Hoover.txt',
#  '1933-Roosevelt.txt',
#  '1937-Roosevelt.txt',
#  '1941-Roosevelt.txt',
#  '1945-Roosevelt.txt',
#  '1949-Truman.txt',
#  '1953-Eisenhower.txt',
# ...

# %%
len(set((word for word in inaugural.words('2009-Obama.txt') if word.startswith('a'))))
# Out:
# 43

# %%
emma=nltk.corpus.gutenberg.words('austen-emma.txt')

# %%
ss=nltk.corpus.gutenberg.words('shakespeare-hamlet.txt')

# %%
from nltk import gutenberg
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-6effd0727c10> in <module>()
# ----> 1 from nltk import gutenberg
#
# ImportError: cannot import name 'gutenberg'

# %%
from nltk.corpus import gutenberg 
gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
austen=nltk.corpus.gutenberg.words('austen-persuasion.txt')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-a0e565e70381> in <module>()
# ----> 1 austen=nltk.corpus.gutenberg.words('austen-persuasion.txt')
#
# NameError: name 'nltk' is not defined

# %%
austen=gutenberg.words('austen-persuasion.txt')

# %%
print(austen)
# Out:
# ['[', 'Persuasion', 'by', 'Jane', 'Austen', '1818', ...]

# %%
print(len(austen))
# Out:
# 98171

# %%
print(len(set(austen)))
# Out:
# 6132

# %%
wordinausten={}

# %%
x=1
for word1 in austen:
    if word1 in wordinausten.keys():
        x+=1
    else:
        wordinausten[word1]=x
print (wordinausten)
# Out:
# {'chamber': 118556, 'paragraph': 462, 'spend': 5326, 'wholly': 89496, 'measure': 175206, 'embellishment': 105224, 'requited': 97958, 'presumed': 12374, 'market': 6060, 'unseen': 128848, 'admired': 191202, 'finale': 854, 'plaguing': 166112, 'quietly': 172306, 'beauty': 18118, 'clearing': 139864, 'exerting': 87010, 'awkward': 4468, 'therefore': 22882, 'Nothing': 17234, 'struggle': 184844, 'resort': 97578, 'condemning': 69156, 'affliction': 82242, 'rapid': 2944, 'Dowager': 113218, 'disdained': 13036, 'know': 16316, 'respectably': 19916, 'ready': 15210, 'unfledged': 147688, 'unheard': 70988, 'choosing': 14146, 'fascination': 137304, 'disingenuous': 160594, 'show': 83552, 'freely': 18476, 'glance': 149438, 'blue': 83248, 'annual': 3262, 'Atlantic': 52764, 'year': 17632, 'shrubbery': 95448, 'worst': 7466, 'exemplify': 66386, 'pockets': 36110, 'preceding': 22540, 'liberal': 11172, 'addressing': 183874, 'acquired': 14484, 'Thames': 22446, 'satisfaction': 8970, 'dissuade': 8814, 'dirt': 15543
# ...

# %%
wordlist=gutenberg.words('austen-persuasion.txt')

# %%
for w in wordlist:
    wordfreq=wordlist.count(w)
print(wordfreq)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-ecb60cb23743> in <module>()
# ----> 1 for w in wordlist:
#       2     wordfreq=wordlist.count(w)
#       3 print(wordfreq)
#
# C:\Users\HP\Anaconda3\lib\site-packages\nltk\corpus\reader\util.py in iterate_from(self, start_tok)
#     286         while filepos < self._eofpos:
#     287             # Read the next block.
# --> 288             self._stream.seek(filepos)
#     289             self._current_toknum = toknum
#     290             self._current_blocknum = block_index
#
# AttributeError: 'NoneType' object has no attribute 'seek'

# %%
x = 'spam' 
while x:
    print(x, end=' ') 
    x = x[1:]
# Out:
# spam pam am m

# %%
for x in ["spam", "eggs", "ham","spam"]:
    print(x, end=' ')
# Out:
# spam eggs ham spam

# %%
prod = 1
for item in [1, 2, 3, 4]: prod *= item

# %%
print(item)
# Out:
# 4

# %%
prod = 1
for item in [1, 2, 3, 4]: 
    item *= item
    print(item)
# Out:
# 1
# 4
# 9
# 16

# %%
print(wordlist)
# Out:
# ['[', 'Persuasion', 'by', 'Jane', 'Austen', '1818', ...]

# %%
wordfreq=[]
x=0
for w in wordlist:
    wordfreq.append(w)
    x=1
    for w1 in wordfreq:
        x+=1
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-6d2941d7dba7> in <module>()
#       5     x=1
#       6     for w1 in wordfreq:
# ----> 7         x+=1
#
# KeyboardInterrupt:

# %%
print(wordfreq)
# Out:
# ['[', 'Persuasion', 'by', 'Jane', 'Austen', '1818', ']', 'Chapter', '1', 'Sir', 'Walter', 'Elliot', ',', 'of', 'Kellynch', 'Hall', ',', 'in', 'Somersetshire', ',', 'was', 'a', 'man', 'who', ',', 'for', 'his', 'own', 'amusement', ',', 'never', 'took', 'up', 'any', 'book', 'but', 'the', 'Baronetage', ';', 'there', 'he', 'found', 'occupation', 'for', 'an', 'idle', 'hour', ',', 'and', 'consolation', 'in', 'a', 'distressed', 'one', ';', 'there', 'his', 'faculties', 'were', 'roused', 'into', 'admiration', 'and', 'respect', ',', 'by', 'contemplating', 'the', 'limited', 'remnant', 'of', 'the', 'earliest', 'patents', ';', 'there', 'any', 'unwelcome', 'sensations', ',', 'arising', 'from', 'domestic', 'affairs', 'changed', 'naturally', 'into', 'pity', 'and', 'contempt', 'as', 'he', 'turned', 'over', 'the', 'almost', 'endless', 'creations', 'of', 'the', 'last', 'century', ';', 'and', 'there', ',', 'if', 'every', 'other', 'leaf', 'were', 'powerless', ',', 'he', 'could', 'read', 'his', 'own', 'his
# ...
